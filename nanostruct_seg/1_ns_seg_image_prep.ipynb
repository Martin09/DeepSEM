# %% [markdown]
# <a href="https://colab.research.google.com/github/Martin09/DeepSEM/blob/master/nanostruct_seg/1_ns_seg_image_prep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1 - Dataset Peparation for NW Yield
# In this notebook we will:
# 1. Import our raw SEM images.
# 2. Crop and export these images as PNG files.
# 3. Upload images for labelling to a new [Labelbox](https://labelbox.com/) project.

# %% [markdown]
# ## 1.1 - Download the dataset

# %%
# # Optional: Save everything to your own GoogleDrive
# from google.colab import drive
# drive.mount('/content/gdrive/')
# %cd "/content/gdrive/My Drive/path/to/save/location"

# Clone the DeepSEM repository
# !rm -rf DeepSEM  # Remove folder if it already exists
# !git clone https://github.com/Martin09/DeepSEM
# Out:
# Cloning into 'DeepSEM'...
# remote: Enumerating objects: 26, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 384 (delta 11), reused 15 (delta 7), pack-reused 358
# Receiving objects: 100% (384/384), 97.97 MiB | 45.15 MiB/s, done.
# Resolving deltas: 100% (159/159), done.

# %%
dataset_dir = './DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs'
# !rm -rf $dataset_dir  # Remove dataset directory if it already exists
# !wget https://github.com/Martin09/DeepSEM/raw/master/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs.zip
# !unzip WJ_NWs_D1-17-02-17-C_rawtiffs.zip -d $dataset_dir
# !rm WJ_NWs_D1-17-02-17-C_rawtiffs.zip
# Out:
# --2020-06-10 10:31:31--  https://github.com/Martin09/DeepSEM/raw/master/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs.zip
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Martin09/DeepSEM/master/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs.zip [following]
# --2020-06-10 10:31:31--  https://raw.githubusercontent.com/Martin09/DeepSEM/master/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30409507 (29M) [application/zip]
# Saving to: ‘WJ_NWs_D1-17-02-17-C_rawtiffs.zip’
#
# WJ_NWs_D1-17-02-17- 100%[===================>]  29.00M  60.4MB/s    in 0.5s
#
# 2020-06-10 10:31:32 (60.4 MB/s) - ‘WJ_NWs_D1-17-02-17-C_rawtiffs.zip’ saved [30409507/30409507]
#
# Archive:  WJ_NWs_D1-17-02-17-C_rawtiffs.zip
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1600 nm pitch 60 nm edge17.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1800 nm pitch 45 nm edge18.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1800 nm pitch 45 nm edge19.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1800 nm pitch 45 nm edge20.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1800 nm pitch 45 nm edge21.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1800 nm pitch 45 nm edge22.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1800 nm pitch 60 nm edge23.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1800 nm pitch 60 nm edge24.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1800 nm pitch 60 nm edge25.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1800 nm pitch 60 nm edge26.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/2000 nm pitch 45 nm edge00.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/2000 nm pitch 45 nm edge01.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/2000 nm pitch 45 nm edge02.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/2000 nm pitch 45 nm edge03.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/2000 nm pitch 45 nm edge04.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/2000 nm pitch 60 nm edge05.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/2000 nm pitch 60 nm edge06.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/2000 nm pitch 60 nm edge07.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/2000 nm pitch 60 nm edge08.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/600 nm pitch 45 nm center07.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/600 nm pitch 45 nm edge02.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/600 nm pitch 45 nm edge04.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/600 nm pitch 45 nm edge05.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/600 nm pitch 45 nm edge06.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/800 nm pitch 45 nm center00.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/800 nm pitch 45 nm center01.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/800 nm pitch 45 nm center02.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/800 nm pitch 45 nm center03.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/800 nm pitch 45 nm center04.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1000 nm pitch 45 nm edge00.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1000 nm pitch 45 nm edge01.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1000 nm pitch 45 nm edge02.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1000 nm pitch 45 nm edge03.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1000 nm pitch 45 nm edge04.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1000 nm pitch 60 nm edge05.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1000 nm pitch 60 nm edge06.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1000 nm pitch 60 nm edge07.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1000 nm pitch 60 nm edge08.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1000 nm pitch 60 nm edge09.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1200 nm pitch 45 nm edge10.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1200 nm pitch 45 nm edge11.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1200 nm pitch 45 nm edge12.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1200 nm pitch 45 nm edge13.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1200 nm pitch 45 nm edge14.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1200 nm pitch 60 nm edge15.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1200 nm pitch 60 nm edge16.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1200 nm pitch 60 nm edge17.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1200 nm pitch 60 nm edge18.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1400 nm pitch 45 nm edge00.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1400 nm pitch 45 nm edge01.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1400 nm pitch 45 nm edge02.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1400 nm pitch 45 nm edge03.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1400 nm pitch 45 nm edge04.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1400 nm pitch 60 nm edge05.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1400 nm pitch 60 nm edge06.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1400 nm pitch 60 nm edge07.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1400 nm pitch 60 nm edge08.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1600 nm pitch 45 nm edge09.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1600 nm pitch 45 nm edge10.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1600 nm pitch 45 nm edge11.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1600 nm pitch 45 nm edge12.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1600 nm pitch 45 nm edge13.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1600 nm pitch 60 nm edge14.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1600 nm pitch 60 nm edge15.tif
#   inflating: ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/1600 nm pitch 60 nm edge16.tif

# %% [markdown]
# ## 1.2 - Export as PNG
# Here we will import the raw TIFF images and export them as PNG files. Since the magnification of these images is relatively high, we only have a a few (<100) objects per image. Thus, we do not need to break the image up into smaller images and we can use the full resolution for training and inference.

# %%
import glob, cv2
from google.colab.patches import cv2_imshow
input_files = glob.glob('./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_rawtiffs/*.tif')

# %% [markdown]
# Import a raw TIFF image to see what it looks like.

# %%
im = cv2.imread(input_files[0], cv2.IMREAD_GRAYSCALE)
cv2_imshow(im)
# Out:
# <PIL.Image.Image image mode=L size=1024x768 at 0x7F44F47B1898>

# %% [markdown]
# Loop over all the raw image files, and subdivide each one then save each sub-image as a separate PNG file.

# %%
output_directory = './DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/'
# !rm -rf $output_directory
# !mkdir $output_directory

# %%
# Loop over the TIFF files
for file in input_files:
    img = cv2.imread(file, cv2.IMREAD_GRAYSCALE) # Import the next image

    # Trim off the overlay bar at bottom of image
    img = img[:688,:]

    # Save as PNG file
    filename = output_directory + file[:-4].split('/')[-1]+'.png'
    print(filename)

    success = cv2.imwrite(filename, (img).astype('uint8')) # Save divided image as PNG

    if not success:
        print("Error, couldn't write image '{}'. Check if output directory exists!".format(filename))
# Out:
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1000 nm pitch 45 nm edge01.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1000 nm pitch 60 nm edge07.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1600 nm pitch 45 nm edge12.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1800 nm pitch 45 nm edge22.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/600 nm pitch 45 nm center07.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/2000 nm pitch 45 nm edge03.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/2000 nm pitch 60 nm edge08.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1400 nm pitch 45 nm edge00.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1000 nm pitch 45 nm edge02.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1600 nm pitch 45 nm edge10.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/600 nm pitch 45 nm edge06.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1000 nm pitch 45 nm edge04.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1800 nm pitch 45 nm edge20.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1200 nm pitch 45 nm edge11.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1600 nm pitch 60 nm edge14.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/800 nm pitch 45 nm center02.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1600 nm pitch 60 nm edge16.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/600 nm pitch 45 nm edge04.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1400 nm pitch 60 nm edge06.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1800 nm pitch 45 nm edge18.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/600 nm pitch 45 nm edge05.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1200 nm pitch 60 nm edge16.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1000 nm pitch 60 nm edge05.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1800 nm pitch 60 nm edge26.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1200 nm pitch 45 nm edge10.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1000 nm pitch 60 nm edge06.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1800 nm pitch 60 nm edge25.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1400 nm pitch 60 nm edge05.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1400 nm pitch 45 nm edge04.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/800 nm pitch 45 nm center04.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1000 nm pitch 60 nm edge09.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1600 nm pitch 60 nm edge17.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1800 nm pitch 60 nm edge24.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1800 nm pitch 45 nm edge19.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/600 nm pitch 45 nm edge02.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1200 nm pitch 45 nm edge13.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1400 nm pitch 45 nm edge01.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1600 nm pitch 45 nm edge11.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1600 nm pitch 45 nm edge09.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1400 nm pitch 45 nm edge03.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/800 nm pitch 45 nm center01.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1000 nm pitch 45 nm edge03.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1800 nm pitch 45 nm edge21.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1000 nm pitch 60 nm edge08.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1600 nm pitch 60 nm edge15.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/2000 nm pitch 45 nm edge00.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/800 nm pitch 45 nm center00.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/2000 nm pitch 45 nm edge04.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1400 nm pitch 60 nm edge08.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/2000 nm pitch 45 nm edge02.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1800 nm pitch 60 nm edge23.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1200 nm pitch 45 nm edge12.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1200 nm pitch 60 nm edge15.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/2000 nm pitch 60 nm edge06.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/2000 nm pitch 60 nm edge05.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1400 nm pitch 60 nm edge07.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1600 nm pitch 45 nm edge13.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1000 nm pitch 45 nm edge00.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/2000 nm pitch 60 nm edge07.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1200 nm pitch 45 nm edge14.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1200 nm pitch 60 nm edge17.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/800 nm pitch 45 nm center03.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1400 nm pitch 45 nm edge02.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1200 nm pitch 60 nm edge18.png
# ./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/2000 nm pitch 45 nm edge01.png

# %% [markdown]
# Visualize what an exported PNG image looks like:

# %%
im = cv2.imread('./DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/1200 nm pitch 60 nm edge17.png', cv2.IMREAD_GRAYSCALE)
cv2_imshow(im)
# Out:
# <PIL.Image.Image image mode=L size=1024x688 at 0x7F44F2D787F0>

# %% [markdown]
# ## 1.3 - Labelling

# %% [markdown]
# Now we are ready to label these images for training the neural network. There are many tools available for creating labelled datasets. In this tutorial I will be using [Labelbox](https://labelbox.com/) for this purpose.
#
# Note: for those that don't care about labelling their own dataset, you can skip ahead to [Notebook 2](https://colab.research.google.com/github/Martin09/DeepSEM/blob/master/nanowire_yield/2_nw_yield_training.ipynb) where I will provide the pre-labelled data for the next steps.
#
# Moving on, let's install the labelbox API first:

# %%
# !pip install labelbox
# Out:
# Collecting labelbox
#   Downloading https://files.pythonhosted.org/packages/c5/0d/1db03e31d4b43791036bf612e9cef2b1960cc15b991ec7b02ab3ed42fb9e/labelbox-2.4-py3-none-any.whl (40kB)
#      |████████████████████████████████| 40kB 2.6MB/s
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.6/dist-packages (from labelbox) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.22.0->labelbox) (2020.4.5.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.22.0->labelbox) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.22.0->labelbox) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.22.0->labelbox) (2.9)
# Installing collected packages: labelbox
# Successfully installed labelbox-2.4

# %% [markdown]
# If you haven't already done so, go ahead and make a free Labelbox account. You can either upload your images to be labelled manually, or you can upload them directly using this script below.
#
# ***If you want to upload the images from this script, you need to create an API key [here](https://app.labelbox.com/account/api-keys) and paste it below:***

# %%
API_KEY = '[INSERT LABELBOX API KEY HERE]'

# %% [markdown]
# Now we can make a new Labelbox project and a new dataset before uploading the sub-divided images.

# %%
# Change these names if you wish
project_name = 'NanoSegmentation'
dataset_name = 'WJ_NWs_D1-17-02-17-C'

# Create a new project and dataset in Labelbox
from labelbox import Client
client = Client(API_KEY)
project = client.create_project(name=project_name)
dataset = client.create_dataset(name=dataset_name, projects=project)

# %%
# Perform a bulk upload of the subdivided PNG files
dataset_dir = './DeepSEM/nanostruct_seg/datasets/WJ_NWs_D1-17-02-17-C_png/'
dataset_files = glob.glob(dataset_dir + '*.png')  # Get a list of the files to upload
dataset.create_data_rows(dataset_files) # Upload the files
# Out:
# <Task ID: ckb98ce4vdtue07161a01ueuu>

# %% [markdown]
# After a few minutes, you should see the new project and images appear in your Labelbox account, [here](https://app.labelbox.com/projects). You can now finish setting up your Labelbox project on the website, including setting your object classes.
#
# Then comes the time-consuming part: labelling your data. For this tutorial, we will only be doing bounding box detection. Therefore, be sure to ***only*** define bounding box objects (not segmentation or polygon objects, for example).
#
# [Notebook 2](https://colab.research.google.com/github/Martin09/DeepSEM/blob/master/nanowire_yield/2_nw_yield_training.ipynb) assumes you have finished your labelling and have exported a labelbox .JSON file with all of your bounding box labels. If you don't have your own labelled dataset don't worry, I will provide that for you. See you there!
